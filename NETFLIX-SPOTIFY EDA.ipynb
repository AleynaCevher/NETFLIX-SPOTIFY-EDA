# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\\SpotifyYoutube.csv')

# %%
data
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
data.shape
# Out:
# (20718, 28)

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  float64
#  7   Energy            20716 non-null  float64
#  8   Key               20716 non-null  float64
#  9   Loudness          20716 non-null  float64
#  10  Speechiness       20716 non-null  float64
#  11  Acousticness      20716 non-null  float64
#  12  Instrumentalness  20716 non-null  float64
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %%
data.transpose()
# Out:
#                                                               0      \
# Artist                                                     Gorillaz
# Url_spotify       https://open.spotify.com/artist/3AA28KZvwAUcZu...
# Track                                                Feel Good Inc.
# Album                                                    Demon Days
# Album_type                                                    album
# Uri                            spotify:track:0d28khcov6AiegSCpG5TuT
# Danceability                                                  0.818
# Energy                                                        0.705
# Key                                                             6.0
# Loudness                                                     -6.679
# Speechiness                                                   0.177
# Acousticness                                                0.00836
# Instrumentalness                                            0.00233
# ...

# %%
data.drop(['Url_spotify','Uri', 'Url_youtube', 'Title', 'Description'],axis =1, inplace = True)

# %%
data
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
data['Likes'] = data['Likes'].fillna(0)
data['Comments'] = data['Comments'].fillna(0)
data.dropna(inplace=True)

# %%
data
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
data.isnull().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
data.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  19691.000000  19691.000000  19691.000000  19691.000000  19691.000000
# mean       0.620921      0.634793      5.294094     -7.641455      0.095205
# std        0.165452      0.213700      3.578829      4.620160      0.106113
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.519000      0.508000      2.000000     -8.785500      0.035700
# 50%        0.639000      0.666000      5.000000     -6.518000      0.050500
# 75%        0.742000      0.797000      8.000000     -4.931000      0.104000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  19691.000000      19691.000000  19691.000000  19691.000000
# mean       0.289590          0.055433      0.191155      0.529019
# std        0.286253          0.192739      0.165137      0.245487
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# List the top 10 most listened-to artists on Spotify.

# %%
df = pd.DataFrame(data)
df_streams = df.groupby('Artist')['Stream'].sum().sort_values(ascending=False)[:10]
fig, ax2 = plt.subplots(figsize=(8, 6))
ax2.set_title('Top 10 most listened')
df_streams.plot(kind='bar', color='maroon', ax=ax2)
ax2.set_xlabel('Artist')
ax2.set_ylabel('Streams')
plt.tight_layout()
plt.show()

# %% [markdown]
# List the top 10 most listened-to artists on Spotify.

# %%
df = pd.DataFrame(data)
df_views = df.groupby('Artist')['Views'].sum().sort_values(ascending=False)[:10]
fig, ax1 = plt.subplots(figsize=(8, 6))
ax1.set_title('Top 10 most listened')
df_views.plot(kind='bar',color='green', ax=ax1)
ax1.set_xlabel('Artist')
ax1.set_ylabel('Views')
plt.tight_layout()
plt.show()

# %% [markdown]
# List the top 10 most-watched songs on Youtube.

# %%
youtube = df.sort_values(by = 'Views', ascending = False)[['Track', 'Artist', 'Views']].head(12)
plt.figure(figsize=(27,9))
sns.barplot(data = youtube, x= 'Track', y='Views', palette = 'Greens_r')
plt.title("Top 10 most-watched songs")
plt.ylabel("İzlenme", color = 'lightgrey')
plt.xlabel("Şarkı", color = 'lightgrey')
plt.show()
# Out:
# C:\Users\aleyn\AppData\Local\Temp\ipykernel_17924\694071610.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = youtube, x= 'Track', y='Views', palette = 'Greens_r')
# c:\Users\aleyn\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\aleyn\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\aleyn\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# List the top 10 most-streamed songs on Spotify.

# %%
spotify = df.sort_values(by = 'Stream', ascending = False)[['Track', 'Artist', 'Stream']].head(12)
plt.figure(figsize=(32,9))
sns.barplot(data = spotify, x= 'Track', y='Stream', palette = 'Reds_r')
plt.title("En Çok Dinlenen 10 Şarkı")
plt.ylabel("İzlenme", color = 'lightgrey')
plt.xlabel("Şarkı", color = 'lightgrey')
plt.show()

# %% [markdown]
# Show the percentage distribution of album genres.

# %%
albüm_tür_sayısı = df['Album_type'].value_counts()
print(albüm_tür_sayısı)
# Out:
# Album_type
# album          14266
# single          4708
# compilation      717
# Name: count, dtype: int64

# %%
colors = ['#ff6f61', '#6b5b95', '#88b04b']

labels = ['Albüm', 'Single', 'EP']
sizes = [72.45, 23.90, 3.64]

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=80, colors=colors)
plt.title('Distribution of Album Genres')
plt.legend(labels, loc='best')
plt.axis('equal')
plt.show()

# %% [markdown]
# Show the distribution of characteristics scores.

# %%
numeric_cols = data.select_dtypes(include='number')
numeric_cols.hist(bins=50,color='orange', figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Danceability'}>,
#         <Axes: title={'center': 'Energy'}>,
#         <Axes: title={'center': 'Key'}>,
#         <Axes: title={'center': 'Loudness'}>],
#        [<Axes: title={'center': 'Speechiness'}>,
#         <Axes: title={'center': 'Acousticness'}>,
#         <Axes: title={'center': 'Instrumentalness'}>,
#         <Axes: title={'center': 'Liveness'}>],
#        [<Axes: title={'center': 'Valence'}>,
#         <Axes: title={'center': 'Tempo'}>,
#         <Axes: title={'center': 'Duration_ms'}>,
#         <Axes: title={'center': 'Views'}>],
#        [<Axes: title={'center': 'Likes'}>,
#         <Axes: title={'center': 'Comments'}>,
#         <Axes: title={'center': 'Stream'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Show the distribution of characteristics in the most-watched songs on YouTube.

# %%
Youtube_En_Çok_8 = df.sort_values('Views', ascending=False).reset_index().head(8)
melt_youtube = Youtube_En_Çok_8.melt(id_vars='Track', value_vars=['Danceability', 'Energy', 'Speechiness', 'Acousticness', 'Valence'], var_name='characteristic', value_name='value')
plt.figure(figsize=(28, 13))
sns.pointplot(x='Track', y='value', hue='characteristic', data=melt_youtube, dodge=True, markers=["o", "s", "D", "^", "v"], linestyles=["-", "--", "-.", ":", "-"])
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1))
plt.title('The Characteristic Features of the 8 Most-Watched Songs on YouTube')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aleyn\AppData\Local\Temp\ipykernel_17924\467651413.py:8: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\aleyn\AppData\Local\Temp\ipykernel_17924\467651413.py:8: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# C:\Users\aleyn\AppData\Local\Temp\ipykernel_17924\467651413.py:8: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.tight_layout()
# C:\Users\aleyn\AppData\Local\Temp\ipykernel_17924\467651413.py:8: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   plt.tight_layout()
# C:\Users\aleyn\AppData\Local\Temp\ipykernel_17924\467651413.py:8: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# c:\Users\aleyn\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
# ...

# %% [markdown]
# Show the distribution of characteristics in the most-watched songs on YouTube.

# %%
Spotify_En_Çok_8 = df.sort_values('Stream', ascending=False).reset_index().head(10)
melt_spotify = Spotify_En_Çok_8.melt(id_vars='Track', value_vars=['Danceability', 'Energy', 'Speechiness', 'Acousticness', 'Valence'], var_name='characteristic', value_name='value')

plt.figure(figsize=(28, 13))
sns.pointplot(x='Track', y='value', hue='characteristic', data=melt_spotify, dodge=True, markers=["o", "s", "D", "^", "v"], linestyles=["-", "--", "-.", ":", "-"])
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1))
plt.title('The Characteristic Features of the 8 Most-Watched Songs on YouTube')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
